# %% [markdown]
# ### DAP PROJECT
# ### BATCH - 3  TITLE - Phone Price Prediction By Its Specifications
# #### A.Chaithanya  - 2111CS010100
# #### G.Chanakya    - 2111CS010102
# #### K.Guna        - 2111CS010160
# #### K.Harshith    - 2111CS010175
# #### N.Harshit     - 2111CS010174

# %% [markdown]
# ### Coloums Explainations
# #### 'Name': Model name of the phone.
# #### 'Brand': Manufacturer or brand of the phone.
# #### 'Model': Specific variant or version of the phone.
# #### 'Battery capacity (mAh)': Amount of energy the phone's battery can store, measured in milliampere-hours.
# #### 'Screen size (inches)': Physical size of the phone's display in inches.
# #### 'Touchscreen': Indicates whether the phone has a touch-sensitive screen.
# #### 'Resolution x' and 'Resolution y': Screen resolution in terms of pixels along the horizontal and vertical axes.
# #### 'Processor': Central Processing Unit (CPU) that powers the phone.
# #### 'RAM (MB)': Random Access Memory, measured in megabytes, used for temporary storage of data during operation.
# #### 'Internal storage (GB)': Built-in storage capacity of the phone, measured in gigabytes.
# #### 'Rear camera': Specifications of the main camera on the back of the phone.
# #### 'Front camera': Specifications of the selfie camera on the front of the phone.
# #### 'Operating system': Software platform on which the phone operates.
# #### 'Wi-Fi': Wireless networking capability.
# #### 'Bluetooth': Wireless technology for data exchange between devices.
# #### 'GPS': Global Positioning System for location tracking.
# #### 'Number of SIMs': Indicates the number of SIM card slots in the phone.
# #### '3G' and '4G/LTE': Cellular network compatibility.
# #### 'Price': Cost of the phone.

# %%
# Import libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #### 1. Load Dataset and Get an Overview

# %%
# Get Dataset File Path
# path = os.path.abspath("")
# Alternatively
path = os.getcwd()
file = path + "/data/ndtv_phones.csv"
# path
file
# Out:
# 'c:\\Users\\smitha\\OneDrive\\Desktop\\Mobile-price/data/ndtv_phones.csv'

# %%
# Load Cars Dataset
df = pd.read_csv(file)
df
# Out:
#       Unnamed: 0                            Name     Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1              1                   Realme X2 Pro    Realme
# 2              2               iPhone 11 Pro Max     Apple
# 3              3                       iPhone 11     Apple
# 4              4                    LG G8X ThinQ        LG
# ...          ...                             ...       ...
# 9513         179            Motorola Moto Z Play  Motorola
# 9514         180             Xiaomi Redmi Note 4    Xiaomi
# 9515         181           Xiaomi Redmi 3S Prime    Xiaomi
# 9516         182                 Motorola Moto Z  Motorola
# 9517         183        Asus ZenFone 3 (ZE552KL)      Asus
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                  4085.0                  6.67
# 1                     X2 Pro                  4000.0                  6.50
# ...

# %%
# Get Top 5 Records
df.head()
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                  4085.0                  6.67
# 1                  X2 Pro                  4000.0                  6.50
# 2       iPhone 11 Pro Max                  3969.0                  6.50
# 3               iPhone 11                  3110.0                  6.10
# 4               G8X ThinQ                  4000.0                  6.40
#
#   Touchscreen  Resolution x  Resolution y  Processor  ...  Rear camera  \
# 0         Yes        1440.0        3120.0        8.0  ...         48.0
# ...

# %%
# Get Last 5 Records
df.tail()
# Out:
#       Unnamed: 0                      Name     Brand                Model  \
# 9513         179      Motorola Moto Z Play  Motorola          Moto Z Play
# 9514         180       Xiaomi Redmi Note 4    Xiaomi         Redmi Note 4
# 9515         181     Xiaomi Redmi 3S Prime    Xiaomi       Redmi 3S Prime
# 9516         182           Motorola Moto Z  Motorola               Moto Z
# 9517         183  Asus ZenFone 3 (ZE552KL)      Asus  ZenFone 3 (ZE552KL)
#
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 9513                  3510.0                   5.5         Yes        1080.0
# 9514                  4100.0                   5.5         Yes        1080.0
# 9515                  4100.0                   5.0         Yes         720.0
# 9516                  2600.0                   5.5         Yes        1440.0
# 9517                  3000.0                   5.5         Yes        1080.0
#
# ...

# %%
# Get Size of Dataset (Rows and Columns)
df.shape
# Out:
# (9518, 22)

# %%
# Get Information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9518 entries, 0 to 9517
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              9518 non-null   int64
#  1   Name                    9518 non-null   object
#  2   Brand                   9518 non-null   object
#  3   Model                   9518 non-null   object
#  4   Battery capacity (mAh)  9518 non-null   float64
#  5   Screen size (inches)    9518 non-null   float64
#  6   Touchscreen             9518 non-null   object
#  7   Resolution x            9518 non-null   float64
#  8   Resolution y            9518 non-null   float64
#  9   Processor               9518 non-null   float64
#  10  RAM (MB)                9518 non-null   float64
#  11  Internal storage (GB)   9518 non-null   float64
#  12  Rear camera             9518 non-null   float64
#  13  Front camera            9518 non-null   float64
# ...

# %%
# Print Column Names Only
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Brand', 'Model', 'Battery capacity (mAh)',
#        'Screen size (inches)', 'Touchscreen', 'Resolution x', 'Resolution y',
#        'Processor', 'RAM (MB)', 'Internal storage (GB)', 'Rear camera',
#        'Front camera', 'Operating system', 'Wi-Fi', 'Bluetooth', 'GPS',
#        'Number of SIMs', '3G', '4G/ LTE', 'Price'],
#       dtype='object')

# %%
# Summary statistics
# if std is 0, that column should be removed from analysis
df.describe().T
# Out:
#                          count          mean           std       min     25%  \
# Unnamed: 0              9518.0    774.255621    418.477190     0.000   402.0
# Battery capacity (mAh)  9518.0   2859.925001    871.786467  1010.000  2200.0
# Screen size (inches)    9518.0      5.241432      0.664915     2.400     5.0
# Resolution x            9518.0    795.328403    270.587233   240.000   640.0
# Resolution y            9518.0   1449.100851    560.587195   320.000   960.0
# Processor               9518.0      5.400269      2.181779     1.000     4.0
# RAM (MB)                9518.0   2355.442203   1634.459524    64.000  1000.0
# Internal storage (GB)   9518.0     28.427043     35.286407     0.064     8.0
# Rear camera             9518.0     11.585397      8.779075     0.000     8.0
# Front camera            9518.0      6.648726      6.155577     0.000     2.0
# Number of SIMs          9518.0      1.845871      0.362543     1.000     2.0
# ...

# %% [markdown]
# # Categorical values
#
# #### Name
# #### Brand
# #### Model
# #### Touchscreen
# #### Operating system
# #### Wi-Fi
# #### Bluetooth
#
# # Numerical values:
# #### Battery capacity (mAh)
#
# #### Screen size (inches)
# #### Resolution x
# #### Resolution y
# #### Processor
# #### RAM (MB).
# #### Internal storage
# #### Rear camera
# #### Front camera
# #### Number of SIMs
# #### 3G
# #### 4G/LTE
# #### Price

# %% [markdown]
# # Data  Preprocessing
# ### Usage of one-hot encoding
# ###  Touchscreen,' 'Wi-Fi,' and 'Bluetooth',GPS,3G,4G/LTE are binary categorical variables (Yes/No), and one-hot encoding can be applied to convert them into numerical format (1 for Yes, 0 for No).

# %%
#replace Yes with 1 and No with 0 in columns(wifi,bluetooth,GPS,3G,4G/LTE)
df = df.replace({'Yes': 1, 'No': 0})

# %%
df = df.replace({'Android': 1, 'iOS': 0})

# %%
#Renameing colmun names for simplecity
df.rename(columns={"Battery capacity (mAh)": "Battery","Screen size (inches)": "Screen_size","Resolution x": "Resolution_x","Resolution y": "Resolution_y","RAM (MB)": "RAM(MB)","Internal storage (GB)": "Internal_storage(GB)","Rear camera": "Rear_camera","Front camera": "Front_camera","Operating system": "OS"}, inplace=True)
df
# Out:
#       Unnamed: 0                            Name     Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1              1                   Realme X2 Pro    Realme
# 2              2               iPhone 11 Pro Max     Apple
# 3              3                       iPhone 11     Apple
# 4              4                    LG G8X ThinQ        LG
# ...          ...                             ...       ...
# 9513         179            Motorola Moto Z Play  Motorola
# 9514         180             Xiaomi Redmi Note 4    Xiaomi
# 9515         181           Xiaomi Redmi 3S Prime    Xiaomi
# 9516         182                 Motorola Moto Z  Motorola
# 9517         183        Asus ZenFone 3 (ZE552KL)      Asus
#
#                        Model  Battery  Screen_size  Touchscreen  Resolution_x  \
# 0     7T Pro McLaren Edition   4085.0         6.67            1        1440.0
# 1                     X2 Pro   4000.0         6.50            1        1080.0
# ...

# %% [markdown]
# #### 2. Check for Null Values and Manipulate Data, if Null values found
# #### Find Null Values - Summary

# %%
# To find the total no.of rows which are missing value in a column
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Brand                   0
# Model                   0
# Battery                 0
# Screen_size             0
# Touchscreen             0
# Resolution_x            0
# Resolution_y            0
# Processor               0
# RAM(MB)                 0
# Internal_storage(GB)    0
# Rear_camera             0
# Front_camera            0
# OS                      0
# Wi-Fi                   0
# Bluetooth               0
# GPS                     0
# Number of SIMs          0
# 3G                      0
# 4G/ LTE                 0
# Price                   0
# dtype: int64

# %%
# This will display rows with at least one null value across all columns
rows_with_null = df[df.isnull().any(axis=1)]
rows_with_null
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Model, Battery, Screen_size, Touchscreen, Resolution_x, Resolution_y, Processor, RAM(MB), Internal_storage(GB), Rear_camera, Front_camera, OS, Wi-Fi, Bluetooth, GPS, Number of SIMs, 3G, 4G/ LTE, Price]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# #### 4. Correlation Analysis to Indetify Dependend and Independent Variables

# %%
# find correlations between all columns
df.corr(method='pearson')
# Out:
#                       Unnamed: 0   Battery  Screen_size  Touchscreen  \
# Unnamed: 0              1.000000 -0.470628    -0.505374    -0.032221
# Battery                -0.470628  1.000000     0.759703     0.098034
# Screen_size            -0.505374  0.759703     1.000000     0.114170
# Touchscreen            -0.032221  0.098034     0.114170     1.000000
# Resolution_x           -0.474992  0.534777     0.622493     0.077791
# Resolution_y           -0.571674  0.607645     0.726116     0.130591
# Processor              -0.456984  0.555119     0.642815     0.093023
# RAM(MB)                -0.561943  0.626632     0.723200     0.091734
# Internal_storage(GB)   -0.509904  0.505192     0.625719     0.064322
# Rear_camera            -0.462294  0.530905     0.610990     0.083978
# Front_camera           -0.514399  0.567136     0.670926     0.079066
# Wi-Fi                  -0.012415  0.000521    -0.012046    -0.008656
# Bluetooth              -0.038969  0.020499     0.028816    -0.011711
# ...

# %% [markdown]
# ## HeatMap

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()

# Heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Sort correlations for 'Price' column in descending order
sorted_corr_msrp = correlation_matrix['Price'].sort_values(ascending=False)
sorted_corr_msrp
# Out:
# Price                   1.000000
# Internal_storage(GB)    0.652028
# RAM(MB)                 0.624837
# Resolution_y            0.596418
# Resolution_x            0.557475
# Screen_size             0.433528
# Rear_camera             0.401700
# Front_camera            0.347801
# Battery                 0.337721
# Processor               0.331157
# 4G/ LTE                 0.188268
# GPS                     0.068717
# Touchscreen             0.046320
# Wi-Fi                   0.027068
# Bluetooth               0.023279
# 3G                     -0.016321
# Number of SIMs         -0.173331
# Unnamed: 0             -0.404057
# Name: Price, dtype: float64

# %% [markdown]
# ## Data Visualization
# #### Create Histogram

# %%
# Select only numeric type of columns by their names as:
df1 = df[['Price','Internal_storage(GB)','RAM(MB)','Screen_size','Rear_camera','Front_camera','Processor','Battery','4G/ LTE','GPS','Touchscreen','Wi-Fi','Bluetooth','3G']]
df1

# Create subplots for the histograms
plt.figure(figsize=(15, 15))

for i, var in enumerate(df1, 1):
    plt.subplot(8, 2, i)
    sns.histplot(df[var], bins=20, kde=True)
    plt.title(f'Histogram of {var}')
    plt.xlabel(var)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Scatter Plot with Regression

# %%
# Select only numeric type of columns by their names as:
df1 = df[['Price','Internal_storage(GB)','RAM(MB)','Screen_size','Rear_camera','Front_camera','Processor','Battery','4G/ LTE','GPS','Touchscreen','Wi-Fi','Bluetooth','3G']]
df1
# Create subplots for the histograms
plt.figure(figsize=(12, 18))

for i, var in enumerate(df1, 1):
    plt.subplot(8,2, i)
    sns.regplot(x=df[var], y='Price', data=df)
    plt.title(f'Scatter Plot with Regression Line - {var}')
    plt.xlabel(var)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5. Handling Outliers

# %% [markdown]
# ### IQR method

# %%
Q1 = np.percentile(df.Price, 25)
Q3 = np.percentile(df.Price, 75)
IQR = Q3 - Q1

# Set a threshold for identifying outliers (e.g., values outside [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR])
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.Price < lower_bound) | (df.Price > upper_bound)]

# %%
print(f"Lower bound: {lower_bound}")
print(f"Upper bound: {upper_bound}")
# Out:
# Lower bound: -5247.5
# Upper bound: 20732.5

# %% [markdown]
# #### Capping Outliers using IQR Method

# %%
# Cap Extreme values identified from Outliers
def cap_outliers(data, lower_threshold, upper_threshold):
    capped_data = np.clip(data, lower_threshold, upper_threshold)
    return capped_data

# Cap the outliers
capped_data = cap_outliers(df.Price, lower_bound, upper_bound)
capped_data

df.loc[:,'Price'] = capped_data

# %% [markdown]
# ### 6. Apply Machine Learning Algorithm

# %%
# Select only numeric type of columns by their names as:
x = df[['Battery','Processor','RAM(MB)','Internal_storage(GB)','Rear_camera','Front_camera','Wi-Fi','Bluetooth','GPS','Number of SIMs','3G','4G/ LTE','Resolution_y','Resolution_x']]
x
# Out:
#       Battery  Processor  RAM(MB)  Internal_storage(GB)  Rear_camera  \
# 0      4085.0        8.0  12000.0                 256.0         48.0
# 1      4000.0        8.0   6000.0                  64.0         64.0
# 2      3969.0        6.0   4000.0                  64.0         12.0
# 3      3110.0        6.0   4000.0                  64.0         12.0
# 4      4000.0        8.0   6000.0                 128.0         12.0
# ...       ...        ...      ...                   ...          ...
# 9513   3510.0        8.0   3000.0                  32.0         16.0
# 9514   4100.0        8.0   2000.0                  32.0         13.0
# 9515   4100.0        8.0   3000.0                  32.0         13.0
# 9516   2600.0        4.0   4000.0                  64.0         13.0
# 9517   3000.0        8.0   4000.0                  64.0         16.0
#
#       Front_camera  Wi-Fi  Bluetooth  GPS  Number of SIMs  3G  4G/ LTE  \
# ...

# %%
x.columns
# Out:
# Index(['Battery', 'Processor', 'RAM(MB)', 'Internal_storage(GB)',
#        'Rear_camera', 'Front_camera', 'Wi-Fi', 'Bluetooth', 'GPS',
#        'Number of SIMs', '3G', '4G/ LTE', 'Resolution_y', 'Resolution_x'],
#       dtype='object')

# %%
# Select only numeric type of columns by their names as:
y = df[['Price']]
y
# Out:
#         Price
# 0     20732.5
# 1     20732.5
# 2     20732.5
# 3     20732.5
# 4     20732.5
# ...       ...
# 9513   8990.0
# 9514   9990.0
# 9515   8000.0
# 9516  11999.0
# 9517  14999.0
#
# [9518 rows x 1 columns]

# %% [markdown]
# ### Import Machine Leaning Libraries and Split Dataset
# ## Training Dataset

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
# Out:
# X_train: (7614, 14)
# X_test: (1904, 14)

# %% [markdown]
# ##  Verifing Ml Algorithms
# ### Create, Fit, Predict and Evaluate Model
# ### 1. Multiple Linear Regression

# %%
# Create a linear regression model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# Fit the model to the training data
lr.fit(X_train, y_train)

# Make predictions on the test data
y_pred = lr.predict(X_test)

# Evaluate the model
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f"R-squared (Coefficient of Determination): {round(r2,2)}")
# Out:
# R-squared (Coefficient of Determination): 0.62

# %% [markdown]
# ### 2. Decision Trees

# %%
from sklearn.tree import DecisionTreeRegressor
# Create a Decision Tree model
dt = DecisionTreeRegressor(max_depth = 3)

# Fit the model to the training data
dt.fit(X_train, y_train)

# Make predictions on the test data
y_pred = dt.predict(X_test)

# Evaluate the model
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f"R-squared (Coefficient of Determination): {round(r2,2)}")
# Out:
# R-squared (Coefficient of Determination): 0.6

# %% [markdown]
# ### 3. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# Create a linear regression model
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
rf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf.predict(X_test)

# Evaluate the model
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f"R-squared (Coefficient of Determination): {round(r2,2)}")
# Out:
# C:\Users\smitha\AppData\Local\Temp\ipykernel_19520\1860458862.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# R-squared (Coefficient of Determination): 0.98

# %% [markdown]
# ### 4. SVR

# %%
from sklearn.svm import SVR

# Create a SVR regression model
model = SVR(kernel='linear')

# Fit the model to the training data
rf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf.predict(X_test)

# Evaluate the model
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f"R-squared (Coefficient of Determination): {round(r2,2)}")
# Out:
# C:\Users\smitha\AppData\Local\Temp\ipykernel_19520\3668257913.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# R-squared (Coefficient of Determination): 0.98

# %%
x
# Out:
#       Battery  Processor  RAM(MB)  Internal_storage(GB)  Rear_camera  \
# 0      4085.0        8.0  12000.0                 256.0         48.0
# 1      4000.0        8.0   6000.0                  64.0         64.0
# 2      3969.0        6.0   4000.0                  64.0         12.0
# 3      3110.0        6.0   4000.0                  64.0         12.0
# 4      4000.0        8.0   6000.0                 128.0         12.0
# ...       ...        ...      ...                   ...          ...
# 9513   3510.0        8.0   3000.0                  32.0         16.0
# 9514   4100.0        8.0   2000.0                  32.0         13.0
# 9515   4100.0        8.0   3000.0                  32.0         13.0
# 9516   2600.0        4.0   4000.0                  64.0         13.0
# 9517   3000.0        8.0   4000.0                  64.0         16.0
#
#       Front_camera  Wi-Fi  Bluetooth  GPS  Number of SIMs  3G  4G/ LTE  \
# ...

# %% [markdown]
# ## Summary of Accuracy of Algorithms
# ##### Multiplie Linear Regresssion: 0.62
# ##### Decision Tree: 0.6
# ##### Randorm Forest: 0.98
# ##### SVR: 0.98
# ###### from the above, considering performancde, Random Forest is taken up for Prediction

# %%
# Make predictions on the New data
Battery=5000
Processor=8
Ram=4000
storage=64
Rear_camera=48
Front_camera=199
Wi_Fi=0
Bluetooth=1
GPS=1
No_of_Sims=1
Three_G=1
LTE_4G=1
Resolution_y=17923
Resolution_x=828

y_pred = rf.predict([[Battery,Processor,Ram,storage,Rear_camera,Front_camera,Wi_Fi,Bluetooth,GPS,No_of_Sims,Three_G,LTE_4G,Resolution_y,Resolution_x]])

print(f"Predicted Price: {round(y_pred[0])}")
# Out:
# Predicted Price: 13993
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Save Model to Pickle file and Make Predictions on Pickle

# %%
# save the model
import pickle
# import joblib
# Save the model during training
# joblib.dump(rf, open("phones_rf.joblib", "wb"))
pickle.dump(rf, open("phones_rf.pkl", "wb"))

# %%
import joblib
joblib.dump(rf,'price_prediction_rf.pkl')
# Out:
# ['price_prediction_rf.pkl']

# %%
# load the model
rf = pickle.load(open("phones_rf.pkl", "rb"))
# Load the model during runtime
# rf= joblib.load("phones_rf.joblid")
# Make predictions on the New data
Battery=5500
Processor=5000
Ram=8000
storage=128
Rear_camera=48
Front_camera=64
Wi_Fi=0
Bluetooth=1
GPS=1
No_of_Sims=1
Three_G=1
LTE_4G=0
Resolution_y=1
Resolution_x=8280

y_pred = rf.predict([[Battery,Processor,Ram,storage,Rear_camera,Front_camera,Wi_Fi,Bluetooth,GPS,No_of_Sims,Three_G,LTE_4G,Resolution_y,Resolution_x]])

print(f"Predicted Price: {round(y_pred[0])}")
# Out:
# Predicted Price: 10688
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
